# %%
import json
import os
from pprint import pprint


import tweepy
import requests

headers = {
    'X-API-Key': os.environ["PP_API_KEY"],
}

# %% [markdown]
# ### load members we want to track

# %%
member_list = []

with open('../data/member_data.json', 'r') as ofile:
    member_list = json.loads(ofile.read())
ofile.close()

# %% [markdown]
# ### just get member ids

# %%
member_ids = []

for member in member_list:
    member_ids.append(member["id"])

# %% [markdown]
# ### pull all votes for these members

# %%
all_recent_member_votes = []

for member_id in member_ids:
    recent_member_votes = json.loads(requests.get("https://api.propublica.org/congress/v1/members/"+ member_id +"/votes.json", headers=headers).text)["results"]
    recent_member_votes = recent_member_votes[0]["votes"]
    pprint(recent_member_votes)
    all_recent_member_votes.append(recent_member_votes)
# Out:
# [{'amendment': {},
#   'bill': {'bill_id': 'sjres64-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres64.json',
#            'latest_action': 'Measure laid before Senate by motion.',
#            'number': 'S.J.Res.64',
#            'sponsor_id': 'T000464',
#            'title': 'A joint resolution providing for congressional '
#                     'disapproval under chapter 8 of title 5, United States '
#                     'Code, of the rule submitted by the Department of the '
#                     'Treasury relating to &quot;Returns by Exempt '
#                     'Organizations and Returns by Certain Non-Exempt '
#                     'Organizations&quot;.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-12',
#   'description': 'A joint resolution providing for congressional disapproval '
#                  'under chapter 8 of title 5, United States Code, of the rule '
#                  'submitted by the Department of the Treasury relating to '
#                  '&quot;Returns by ...',
#   'member_id': 'F000062',
#   'position': 'Yes',
#   'question': 'On the Joint Resolution',
#   'result': 'Joint Resolution Passed',
#   'roll_call': '260',
#   'session': '2',
#   'time': '12:27:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/260.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr2-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr2.json',
#            'latest_action': 'Rules Committee Resolution H. Res. 1176 Reported '
#                             'to House. The resolution provides for '
#                             'consideration of the Conference Report to '
#                             'accompany H.R. 2. The resolution provides for one '
#                             'hour of debate and one motion to recommit.',
#            'number': 'H.R.2',
#            'sponsor_id': 'C001062',
#            'title': 'To provide for the reform and continuation of '
#                     'agricultural and other programs of the Department of '
#                     'Agriculture through fiscal year 2023, and for other '
#                     'purposes.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'A bill to provide for the reform and continuation of '
#                  'agricultural and other programs of the Department of '
#                  'Agriculture through fiscal year 2023, and for other '
#                  'purposes.',
#   'member_id': 'F000062',
#   'position': 'Yes',
#   'question': 'On the Conference Report',
#   'result': 'Conference Report Agreed to',
#   'roll_call': '259',
#   'session': '2',
#   'time': '15:58:00',
#   'total': {'no': 13, 'not_voting': 0, 'present': 0, 'yes': 87},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/259.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2117-115',
#            'latest_action': None,
#            'number': 'PN2117',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Jonathan A. Kobes, of South Dakota, to be United States '
#                  'Circuit Judge for the Eighth Circuit',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Jonathan A. Kobes',
#                  'nomination_id': 'PN2117-115',
#                  'number': 'PN2117'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '258',
#   'session': '2',
#   'time': '14:17:00',
#   'total': {'no': 50, 'not_voting': 0, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/258.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1803-115',
#            'latest_action': None,
#            'number': 'PN1803',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Justin George Muzinich, of New York, to be Deputy Secretary '
#                  'of the Treasury',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of the Treasury',
#                  'name': 'Justin George Muzinich',
#                  'nomination_id': 'PN1803-115',
#                  'number': 'PN1803'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '257',
#   'session': '2',
#   'time': '11:00:00',
#   'total': {'no': 44, 'not_voting': 1, 'present': 0, 'yes': 55},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/257.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1803-115',
#            'latest_action': None,
#            'number': 'PN1803',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-10',
#   'description': 'Justin George Muzinich, of New York, to be Deputy Secretary '
#                  'of the Treasury',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of the Treasury',
#                  'name': 'Justin George Muzinich',
#                  'nomination_id': 'PN1803-115',
#                  'number': 'PN1803'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '256',
#   'session': '2',
#   'time': '17:32:00',
#   'total': {'no': 43, 'not_voting': 2, 'present': 0, 'yes': 55},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/256.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2170-115',
#            'latest_action': None,
#            'number': 'PN2170',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-06',
#   'description': 'Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of '
#                  'Consumer Financial Protection for a term of five years',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Bureau of Consumer Financial Protection',
#                  'name': 'Kathleen Laura Kraninger',
#                  'nomination_id': 'PN2170-115',
#                  'number': 'PN2170'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '255',
#   'session': '2',
#   'time': '13:34:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/255.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2556-115',
#            'latest_action': None,
#            'number': 'PN2556',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-06',
#   'description': 'Bernard L. McNamee, of Virginia, to be a Member of the '
#                  'Federal Energy Regulatory Commission for the remainder of '
#                  'the term expiring June 30, 2020',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Federal Energy Regulatory Commission',
#                  'name': 'Bernard L. McNamee',
#                  'nomination_id': 'PN2556-115',
#                  'number': 'PN2556'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '254',
#   'session': '2',
#   'time': '12:00:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/254.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2556-115',
#            'latest_action': None,
#            'number': 'PN2556',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-05',
#   'description': 'Bernard L. McNamee, of Virginia, to be a Member of the '
#                  'Federal Energy Regulatory Commission for the remainder of '
#                  'the term expiring June 30, 2020',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Federal Energy Regulatory Commission',
#                  'name': 'Bernard L. McNamee',
#                  'nomination_id': 'PN2556-115',
#                  'number': 'PN2556'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '253',
#   'session': '2',
#   'time': '16:05:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/253.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2170-115',
#            'latest_action': None,
#            'number': 'PN2170',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of '
#                  'Consumer Financial Protection for a term of five years',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Bureau of Consumer Financial Protection',
#                  'name': 'Kathleen Laura Kraninger',
#                  'nomination_id': 'PN2170-115',
#                  'number': 'PN2170'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '252',
#   'session': '2',
#   'time': '13:28:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/252.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2117-115',
#            'latest_action': None,
#            'number': 'PN2117',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'Jonathan A. Kobes, of South Dakota, to be United States '
#                  'Circuit Judge for the Eighth Circuit',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Jonathan A. Kobes',
#                  'nomination_id': 'PN2117-115',
#                  'number': 'PN2117'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '251',
#   'session': '2',
#   'time': '12:14:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 1, 'yes': 49},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/251.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'sjres54-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres54.json',
#            'latest_action': 'Placed on Senate Legislative Calendar under '
#                             'General Orders. Calendar No. 682.',
#            'number': 'S.J.Res.54',
#            'sponsor_id': 'S000033',
#            'title': 'A joint resolution to direct the removal of United States '
#                     'Armed Forces from hostilities in the Republic of Yemen '
#                     'that have not been authorized by Congress.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'A joint resolution to direct the removal of United States '
#                  'Armed Forces from hostilities in the Republic of Yemen that '
#                  'have not been authorized by Congress.',
#   'member_id': 'F000062',
#   'position': 'Yes',
#   'question': 'On the Motion to Discharge',
#   'result': 'Motion to Discharge Agreed to',
#   'roll_call': '250',
#   'session': '2',
#   'time': '15:52:00',
#   'total': {'no': 37, 'not_voting': 0, 'present': 0, 'yes': 63},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/250.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1412-115',
#            'latest_action': None,
#            'number': 'PN1412',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'Thomas Alvin Farr, of North Carolina, to be United States '
#                  'District Judge for the Eastern District of North Carolina',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Thomas Alvin Farr',
#                  'nomination_id': 'PN1412-115',
#                  'number': 'PN1412'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '249',
#   'session': '2',
#   'time': '12:56:00',
#   'total': {'no': 50, 'not_voting': 0, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/249.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2049-115',
#            'latest_action': None,
#            'number': 'PN2049',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary '
#                  'of Commerce',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of Commerce',
#                  'name': 'Karen Dunn Kelley',
#                  'nomination_id': 'PN2049-115',
#                  'number': 'PN2049'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '248',
#   'session': '2',
#   'time': '12:19:00',
#   'total': {'no': 38, 'not_voting': 0, 'present': 0, 'yes': 62},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/248.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2049-115',
#            'latest_action': None,
#            'number': 'PN2049',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary '
#                  'of Commerce',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of Commerce',
#                  'name': 'Karen Dunn Kelley',
#                  'nomination_id': 'PN2049-115',
#                  'number': 'PN2049'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '247',
#   'session': '2',
#   'time': '12:54:00',
#   'total': {'no': 37, 'not_voting': 1, 'present': 0, 'yes': 62},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/247.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn889-115',
#            'latest_action': None,
#            'number': 'PN889',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Stephen Alexander Vaden, of Tennessee, to be General Counsel '
#                  'of the Department of Agriculture',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of Agriculture',
#                  'name': 'Stephen Alexander Vaden',
#                  'nomination_id': 'PN889-115',
#                  'number': 'PN889'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '246',
#   'session': '2',
#   'time': '12:16:00',
#   'total': {'no': 46, 'not_voting': 1, 'present': 0, 'yes': 53},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/246.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn889-115',
#            'latest_action': None,
#            'number': 'PN889',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-26',
#   'description': 'Stephen Alexander Vaden, of Tennessee, to be General Counsel '
#                  'of the Department of Agriculture',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Department of Agriculture',
#                  'name': 'Stephen Alexander Vaden',
#                  'nomination_id': 'PN889-115',
#                  'number': 'PN889'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '245',
#   'session': '2',
#   'time': '17:30:00',
#   'total': {'no': 45, 'not_voting': 6, 'present': 0, 'yes': 49},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/245.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1860-115',
#            'latest_action': None,
#            'number': 'PN1860',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-15',
#   'description': 'Michelle Bowman, of Kansas, to be a Member of the Board of '
#                  'Governors of the Federal Reserve System for the unexpired '
#                  'term of fourteen years from February 1, 2006',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Federal Reserve System',
#                  'name': 'Michelle Bowman',
#                  'nomination_id': 'PN1860-115',
#                  'number': 'PN1860'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '244',
#   'session': '2',
#   'time': '13:47:00',
#   'total': {'no': 34, 'not_voting': 2, 'present': 0, 'yes': 64},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/244.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'sjres65-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres65.json',
#            'latest_action': 'Motion to discharge Senate Committee on Foreign '
#                             'Relations tabled by Yea-Nay Vote. 77 - 21. Record '
#                             'Vote Number: 243.',
#            'number': 'S.J.Res.65',
#            'sponsor_id': 'P000603',
#            'title': 'A joint resolution relating to the disapproval of the '
#                     'proposed export to the Government of the Kingdom of '
#                     'Bahrain of certain defense articles and services.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-15',
#   'description': 'A joint resolution relating to the disapproval of the '
#                  'proposed export to the Government of the Kingdom of Bahrain '
#                  'of certain defense articles and services.',
#   'member_id': 'F000062',
#   'position': 'No',
#   'question': 'On the Motion to Table',
#   'result': 'Motion to Table Agreed to',
#   'roll_call': '243',
#   'session': '2',
#   'time': '12:25:00',
#   'total': {'no': 21, 'not_voting': 2, 'present': 0, 'yes': 77},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/243.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1860-115',
#            'latest_action': None,
#            'number': 'PN1860',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-14',
#   'description': 'Michelle Bowman, of Kansas, to be a Member of the Board of '
#                  'Governors of the Federal Reserve System for the unexpired '
#                  'term of fourteen years from February 1, 2006',
#   'member_id': 'F000062',
#   'nomination': {'agency': 'Federal Reserve System',
#                  'name': 'Michelle Bowman',
#                  'nomination_id': 'PN1860-115',
#                  'number': 'PN1860'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '242',
#   'session': '2',
#   'time': '14:48:00',
#   'total': {'no': 36, 'not_voting': 1, 'present': 0, 'yes': 63},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/242.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 's140-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/s140.json',
#            'latest_action': 'Became Public Law No: 115-282.',
#            'number': 'S.140',
#            'sponsor_id': 'F000444',
#            'title': 'A bill to amend the White Mountain Apache Tribe Water '
#                     'Rights Quantification Act of 2010 to clarify the use of '
#                     'amounts in the WMAT Settlement Fund.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-14',
#   'description': 'A bill to amend the White Mountain Apache Tribe Water Rights '
#                  'Quantification Act of 2010 to clarify the use of amounts in '
#                  'the WMAT Settlement Fund.',
#   'member_id': 'F000062',
#   'position': 'Yes',
#   'question': 'On the Motion',
#   'result': 'Motion Agreed to',
#   'roll_call': '241',
#   'session': '2',
#   'time': '14:21:00',
#   'total': {'no': 6, 'not_voting': 0, 'present': 0, 'yes': 94},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/241.json'}]
# [{'amendment': {},
#   'bill': {'bill_id': 'sjres64-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres64.json',
#            'latest_action': 'Measure laid before Senate by motion.',
#            'number': 'S.J.Res.64',
#            'sponsor_id': 'T000464',
#            'title': 'A joint resolution providing for congressional '
#                     'disapproval under chapter 8 of title 5, United States '
#                     'Code, of the rule submitted by the Department of the '
#                     'Treasury relating to &quot;Returns by Exempt '
#                     'Organizations and Returns by Certain Non-Exempt '
#                     'Organizations&quot;.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-12',
#   'description': 'A joint resolution providing for congressional disapproval '
#                  'under chapter 8 of title 5, United States Code, of the rule '
#                  'submitted by the Department of the Treasury relating to '
#                  '&quot;Returns by ...',
#   'member_id': 'H001075',
#   'position': 'Yes',
#   'question': 'On the Joint Resolution',
#   'result': 'Joint Resolution Passed',
#   'roll_call': '260',
#   'session': '2',
#   'time': '12:27:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/260.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr2-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr2.json',
#            'latest_action': 'Rules Committee Resolution H. Res. 1176 Reported '
#                             'to House. The resolution provides for '
#                             'consideration of the Conference Report to '
#                             'accompany H.R. 2. The resolution provides for one '
#                             'hour of debate and one motion to recommit.',
#            'number': 'H.R.2',
#            'sponsor_id': 'C001062',
#            'title': 'To provide for the reform and continuation of '
#                     'agricultural and other programs of the Department of '
#                     'Agriculture through fiscal year 2023, and for other '
#                     'purposes.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'A bill to provide for the reform and continuation of '
#                  'agricultural and other programs of the Department of '
#                  'Agriculture through fiscal year 2023, and for other '
#                  'purposes.',
#   'member_id': 'H001075',
#   'position': 'Yes',
#   'question': 'On the Conference Report',
#   'result': 'Conference Report Agreed to',
#   'roll_call': '259',
#   'session': '2',
#   'time': '15:58:00',
#   'total': {'no': 13, 'not_voting': 0, 'present': 0, 'yes': 87},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/259.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2117-115',
#            'latest_action': None,
#            'number': 'PN2117',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Jonathan A. Kobes, of South Dakota, to be United States '
#                  'Circuit Judge for the Eighth Circuit',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Jonathan A. Kobes',
#                  'nomination_id': 'PN2117-115',
#                  'number': 'PN2117'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '258',
#   'session': '2',
#   'time': '14:17:00',
#   'total': {'no': 50, 'not_voting': 0, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/258.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1803-115',
#            'latest_action': None,
#            'number': 'PN1803',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Justin George Muzinich, of New York, to be Deputy Secretary '
#                  'of the Treasury',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of the Treasury',
#                  'name': 'Justin George Muzinich',
#                  'nomination_id': 'PN1803-115',
#                  'number': 'PN1803'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '257',
#   'session': '2',
#   'time': '11:00:00',
#   'total': {'no': 44, 'not_voting': 1, 'present': 0, 'yes': 55},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/257.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1803-115',
#            'latest_action': None,
#            'number': 'PN1803',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-10',
#   'description': 'Justin George Muzinich, of New York, to be Deputy Secretary '
#                  'of the Treasury',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of the Treasury',
#                  'name': 'Justin George Muzinich',
#                  'nomination_id': 'PN1803-115',
#                  'number': 'PN1803'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '256',
#   'session': '2',
#   'time': '17:32:00',
#   'total': {'no': 43, 'not_voting': 2, 'present': 0, 'yes': 55},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/256.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2170-115',
#            'latest_action': None,
#            'number': 'PN2170',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-06',
#   'description': 'Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of '
#                  'Consumer Financial Protection for a term of five years',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Bureau of Consumer Financial Protection',
#                  'name': 'Kathleen Laura Kraninger',
#                  'nomination_id': 'PN2170-115',
#                  'number': 'PN2170'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '255',
#   'session': '2',
#   'time': '13:34:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/255.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2556-115',
#            'latest_action': None,
#            'number': 'PN2556',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-06',
#   'description': 'Bernard L. McNamee, of Virginia, to be a Member of the '
#                  'Federal Energy Regulatory Commission for the remainder of '
#                  'the term expiring June 30, 2020',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Federal Energy Regulatory Commission',
#                  'name': 'Bernard L. McNamee',
#                  'nomination_id': 'PN2556-115',
#                  'number': 'PN2556'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '254',
#   'session': '2',
#   'time': '12:00:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/254.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2556-115',
#            'latest_action': None,
#            'number': 'PN2556',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-12-05',
#   'description': 'Bernard L. McNamee, of Virginia, to be a Member of the '
#                  'Federal Energy Regulatory Commission for the remainder of '
#                  'the term expiring June 30, 2020',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Federal Energy Regulatory Commission',
#                  'name': 'Bernard L. McNamee',
#                  'nomination_id': 'PN2556-115',
#                  'number': 'PN2556'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '253',
#   'session': '2',
#   'time': '16:05:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/253.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2170-115',
#            'latest_action': None,
#            'number': 'PN2170',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of '
#                  'Consumer Financial Protection for a term of five years',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Bureau of Consumer Financial Protection',
#                  'name': 'Kathleen Laura Kraninger',
#                  'nomination_id': 'PN2170-115',
#                  'number': 'PN2170'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '252',
#   'session': '2',
#   'time': '13:28:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/252.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2117-115',
#            'latest_action': None,
#            'number': 'PN2117',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'Jonathan A. Kobes, of South Dakota, to be United States '
#                  'Circuit Judge for the Eighth Circuit',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Jonathan A. Kobes',
#                  'nomination_id': 'PN2117-115',
#                  'number': 'PN2117'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '251',
#   'session': '2',
#   'time': '12:14:00',
#   'total': {'no': 49, 'not_voting': 1, 'present': 1, 'yes': 49},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/251.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'sjres54-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres54.json',
#            'latest_action': 'Placed on Senate Legislative Calendar under '
#                             'General Orders. Calendar No. 682.',
#            'number': 'S.J.Res.54',
#            'sponsor_id': 'S000033',
#            'title': 'A joint resolution to direct the removal of United States '
#                     'Armed Forces from hostilities in the Republic of Yemen '
#                     'that have not been authorized by Congress.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'A joint resolution to direct the removal of United States '
#                  'Armed Forces from hostilities in the Republic of Yemen that '
#                  'have not been authorized by Congress.',
#   'member_id': 'H001075',
#   'position': 'Yes',
#   'question': 'On the Motion to Discharge',
#   'result': 'Motion to Discharge Agreed to',
#   'roll_call': '250',
#   'session': '2',
#   'time': '15:52:00',
#   'total': {'no': 37, 'not_voting': 0, 'present': 0, 'yes': 63},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/250.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1412-115',
#            'latest_action': None,
#            'number': 'PN1412',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'Thomas Alvin Farr, of North Carolina, to be United States '
#                  'District Judge for the Eastern District of North Carolina',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'The Judiciary',
#                  'name': 'Thomas Alvin Farr',
#                  'nomination_id': 'PN1412-115',
#                  'number': 'PN1412'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '249',
#   'session': '2',
#   'time': '12:56:00',
#   'total': {'no': 50, 'not_voting': 0, 'present': 0, 'yes': 50},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/249.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2049-115',
#            'latest_action': None,
#            'number': 'PN2049',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-28',
#   'description': 'Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary '
#                  'of Commerce',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of Commerce',
#                  'name': 'Karen Dunn Kelley',
#                  'nomination_id': 'PN2049-115',
#                  'number': 'PN2049'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '248',
#   'session': '2',
#   'time': '12:19:00',
#   'total': {'no': 38, 'not_voting': 0, 'present': 0, 'yes': 62},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/248.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn2049-115',
#            'latest_action': None,
#            'number': 'PN2049',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary '
#                  'of Commerce',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of Commerce',
#                  'name': 'Karen Dunn Kelley',
#                  'nomination_id': 'PN2049-115',
#                  'number': 'PN2049'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '247',
#   'session': '2',
#   'time': '12:54:00',
#   'total': {'no': 37, 'not_voting': 1, 'present': 0, 'yes': 62},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/247.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn889-115',
#            'latest_action': None,
#            'number': 'PN889',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Stephen Alexander Vaden, of Tennessee, to be General Counsel '
#                  'of the Department of Agriculture',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of Agriculture',
#                  'name': 'Stephen Alexander Vaden',
#                  'nomination_id': 'PN889-115',
#                  'number': 'PN889'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '246',
#   'session': '2',
#   'time': '12:16:00',
#   'total': {'no': 46, 'not_voting': 1, 'present': 0, 'yes': 53},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/246.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn889-115',
#            'latest_action': None,
#            'number': 'PN889',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-26',
#   'description': 'Stephen Alexander Vaden, of Tennessee, to be General Counsel '
#                  'of the Department of Agriculture',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Department of Agriculture',
#                  'name': 'Stephen Alexander Vaden',
#                  'nomination_id': 'PN889-115',
#                  'number': 'PN889'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '245',
#   'session': '2',
#   'time': '17:30:00',
#   'total': {'no': 45, 'not_voting': 6, 'present': 0, 'yes': 49},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/245.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1860-115',
#            'latest_action': None,
#            'number': 'PN1860',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-15',
#   'description': 'Michelle Bowman, of Kansas, to be a Member of the Board of '
#                  'Governors of the Federal Reserve System for the unexpired '
#                  'term of fourteen years from February 1, 2006',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Federal Reserve System',
#                  'name': 'Michelle Bowman',
#                  'nomination_id': 'PN1860-115',
#                  'number': 'PN1860'},
#   'position': 'No',
#   'question': 'On the Nomination',
#   'result': 'Nomination Confirmed',
#   'roll_call': '244',
#   'session': '2',
#   'time': '13:47:00',
#   'total': {'no': 34, 'not_voting': 2, 'present': 0, 'yes': 64},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/244.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'sjres65-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/sjres65.json',
#            'latest_action': 'Motion to discharge Senate Committee on Foreign '
#                             'Relations tabled by Yea-Nay Vote. 77 - 21. Record '
#                             'Vote Number: 243.',
#            'number': 'S.J.Res.65',
#            'sponsor_id': 'P000603',
#            'title': 'A joint resolution relating to the disapproval of the '
#                     'proposed export to the Government of the Kingdom of '
#                     'Bahrain of certain defense articles and services.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-15',
#   'description': 'A joint resolution relating to the disapproval of the '
#                  'proposed export to the Government of the Kingdom of Bahrain '
#                  'of certain defense articles and services.',
#   'member_id': 'H001075',
#   'position': 'No',
#   'question': 'On the Motion to Table',
#   'result': 'Motion to Table Agreed to',
#   'roll_call': '243',
#   'session': '2',
#   'time': '12:25:00',
#   'total': {'no': 21, 'not_voting': 2, 'present': 0, 'yes': 77},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/243.json'},
#  {'amendment': {},
#   'bill': {'api_uri': None,
#            'bill_id': 'pn1860-115',
#            'latest_action': None,
#            'number': 'PN1860',
#            'title': None},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-14',
#   'description': 'Michelle Bowman, of Kansas, to be a Member of the Board of '
#                  'Governors of the Federal Reserve System for the unexpired '
#                  'term of fourteen years from February 1, 2006',
#   'member_id': 'H001075',
#   'nomination': {'agency': 'Federal Reserve System',
#                  'name': 'Michelle Bowman',
#                  'nomination_id': 'PN1860-115',
#                  'number': 'PN1860'},
#   'position': 'No',
#   'question': 'On the Cloture Motion',
#   'result': 'Cloture Motion Agreed to',
#   'roll_call': '242',
#   'session': '2',
#   'time': '14:48:00',
#   'total': {'no': 36, 'not_voting': 1, 'present': 0, 'yes': 63},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/242.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 's140-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/s140.json',
#            'latest_action': 'Became Public Law No: 115-282.',
#            'number': 'S.140',
#            'sponsor_id': 'F000444',
#            'title': 'A bill to amend the White Mountain Apache Tribe Water '
#                     'Rights Quantification Act of 2010 to clarify the use of '
#                     'amounts in the WMAT Settlement Fund.'},
#   'chamber': 'Senate',
#   'congress': '115',
#   'date': '2018-11-14',
#   'description': 'A bill to amend the White Mountain Apache Tribe Water Rights '
#                  'Quantification Act of 2010 to clarify the use of amounts in '
#                  'the WMAT Settlement Fund.',
#   'member_id': 'H001075',
#   'position': 'No',
#   'question': 'On the Motion',
#   'result': 'Motion Agreed to',
#   'roll_call': '241',
#   'session': '2',
#   'time': '14:21:00',
#   'total': {'no': 6, 'not_voting': 0, 'present': 0, 'yes': 94},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/241.json'}]
# [{'amendment': {},
#   'bill': {'bill_id': 's825-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/s825.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'S 825',
#            'sponsor_id': 'M001153',
#            'title': 'A bill to provide for the conveyance of certain property '
#                     'to the Southeast Alaska Regional Health Consortium '
#                     'located in Sitka, Alaska, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Southeast Alaska Regional Health Consortium Land Transfer '
#                  'Act of 2017',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '430',
#   'session': '2',
#   'time': '17:06:00',
#   'total': {'no': 3, 'not_voting': 26, 'present': 0, 'yes': 403},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/430.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 's3029-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/s3029.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'S 3029',
#            'sponsor_id': 'A000360',
#            'title': 'A bill to revise and extend the Prematurity Research '
#                     'Expansion and Education for Mothers who deliver Infants '
#                     'Early Act (PREEMIE Act).'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'PREEMIE Reauthorization Act',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '429',
#   'session': '2',
#   'time': '16:57:00',
#   'total': {'no': 3, 'not_voting': 23, 'present': 0, 'yes': 406},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/429.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr7217-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr7217.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'H R 7217',
#            'sponsor_id': 'B000213',
#            'title': 'To amend title XIX of the Social Security Act to provide '
#                     'States with the option of providing coordinated care for '
#                     'children with complex medical conditions through a health '
#                     'home, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-12-11',
#   'description': 'Improving Medicaid Programs and Opportunities for Eligible '
#                  'Beneficiaries Act',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '428',
#   'session': '2',
#   'time': '16:46:00',
#   'total': {'no': 11, 'not_voting': 21, 'present': 0, 'yes': 400},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/428.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr3008-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr3008.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Energy and Natural '
#                             'Resources.',
#            'number': 'H R 3008',
#            'sponsor_id': 'C001062',
#            'title': 'To authorize the Secretary of the Interior to conduct a '
#                     'special resource study of the George W. Bush Childhood '
#                     'Home, located at 1412 West Ohio Avenue, Midland, Texas, '
#                     'and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-12-10',
#   'description': 'George W. Bush Childhood Home Study Act',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '427',
#   'session': '2',
#   'time': '19:02:00',
#   'total': {'no': 4, 'not_voting': 44, 'present': 2, 'yes': 382},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/427.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hres792-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hres792.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'H RES 792',
#            'sponsor_id': 'S000248',
#            'title': 'Urging the Secretary of the Interior to recognize the '
#                     'historical significance of Roberto Clemente&#39;s place '
#                     'of death near Piñones in Loíza, Puerto Rico, by adding it '
#                     'to the National Register of Historic Places.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-12-10',
#   'description': 'Urging the Secretary of the Interior to recognize the '
#                  'historical significance of Roberto Clemente’s place of death '
#                  'near Pinones in Loiza, Puerto Rico, by adding it to the '
#                  'National Register ...',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Agree, as Amended',
#   'result': 'Passed',
#   'roll_call': '426',
#   'session': '2',
#   'time': '18:53:00',
#   'total': {'no': 1, 'not_voting': 44, 'present': 2, 'yes': 385},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/426.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6901-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6901.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Homeland Security '
#                             'and Governmental Affairs.',
#            'number': 'H R 6901',
#            'sponsor_id': 'H001073',
#            'title': 'To amend chapter 36 of title 44, United States Code, to '
#                     'make certain changes relating to electronic Government '
#                     'services, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-30',
#   'description': 'Federal CIO Authorization Act of 2018',
#   'member_id': 'H001048',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'result': 'Passed',
#   'roll_call': '425',
#   'session': '2',
#   'time': '10:26:00',
#   'total': {'no': 0, 'not_voting': 41, 'present': 0, 'yes': 391},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/425.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr7187-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr7187.json',
#            'latest_action': 'Became Public Law No: 115-281.',
#            'number': 'H R 7187',
#            'sponsor_id': 'M001193',
# ...
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'result': 'Passed',
#   'roll_call': '425',
#   'session': '2',
#   'time': '10:26:00',
#   'total': {'no': 0, 'not_voting': 41, 'present': 0, 'yes': 391},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/425.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr7187-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr7187.json',
#            'latest_action': 'Became Public Law No: 115-281.',
#            'number': 'H R 7187',
#            'sponsor_id': 'M001193',
#            'title': 'To extend the National Flood Insurance Program until '
#                     'December 7, 2018.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'To extend the National Flood Insurance Program until '
#                  'December 7, 2018.',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '424',
#   'session': '2',
#   'time': '19:04:00',
#   'total': {'no': 46, 'not_voting': 36, 'present': 0, 'yes': 350},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/424.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hres1160-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hres1160.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'H RES 1160',
#            'sponsor_id': 'S000250',
#            'title': 'Providing for consideration of the Senate amendment to '
#                     'the bill (H.R. 88) to modify the boundary of the Shiloh '
#                     'National Military Park located in Tennessee and '
#                     'Mississippi, to establish Parker&#39;s Crossroads '
#                     'Battlefield as an affiliated area of the National Park '
#                     'System, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-29',
#   'description': 'Providing for consideration of the Senate amendment to the '
#                  'bill (H.R. 88) to modify the boundary of the Shiloh National '
#                  'Military Park located in Tennessee and Mississippi, to '
#                  'establish Parker’s ...',
#   'member_id': 'G000585',
#   'position': 'No',
#   'question': 'On Agreeing to the Resolution',
#   'result': 'Passed',
#   'roll_call': '423',
#   'session': '2',
#   'time': '18:54:00',
#   'total': {'no': 181, 'not_voting': 32, 'present': 0, 'yes': 219},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/423.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6207-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6207.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Foreign Relations.',
#            'number': 'H R 6207',
#            'sponsor_id': 'S000522',
#            'title': 'To support democracy and accountability in the Democratic '
#                     'Republic of the Congo, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Democratic Republic of the Congo Democracy and '
#                  'Accountability Act of 2018',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'result': 'Passed',
#   'roll_call': '422',
#   'session': '2',
#   'time': '19:31:00',
#   'total': {'no': 11, 'not_voting': 46, 'present': 0, 'yes': 374},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/422.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr5273-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr5273.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Foreign Relations.',
#            'number': 'H R 5273',
#            'sponsor_id': 'E000179',
#            'title': 'To reduce global fragility and violence by improving the '
#                     'capacity of the United States to reduce and address the '
#                     'causes of violence, violent conflict, and fragility in '
#                     'pilot countries, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-27',
#   'description': 'Global Fragility and Violence Reduction Act of 2018',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'result': 'Passed',
#   'roll_call': '421',
#   'session': '2',
#   'time': '19:08:00',
#   'total': {'no': 16, 'not_voting': 38, 'present': 0, 'yes': 376},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/421.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6784-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6784.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Environment and '
#                             'Public Works.',
#            'number': 'H R 6784',
#            'sponsor_id': 'D000614',
#            'title': 'To provide for removal of the gray wolf in the contiguous '
#                     '48 States from the List of Endangered and Threatened '
#                     'Wildlife published under the Endangered Species Act of '
#                     '1973.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-16',
#   'description': 'Manage our Wolves Act',
#   'member_id': 'G000585',
#   'position': 'No',
#   'question': 'On Passage',
#   'result': 'Passed',
#   'roll_call': '420',
#   'session': '2',
#   'time': '11:06:00',
#   'total': {'no': 180, 'not_voting': 54, 'present': 0, 'yes': 196},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/420.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr5787-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr5787.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Environment and '
#                             'Public Works.',
#            'number': 'H R 5787',
#            'sponsor_id': 'D000628',
#            'title': 'To amend the Coastal Barrier Resources Act to give effect '
#                     'to more accurate maps of units of the John H. Chafee '
#                     'Coastal Barrier Resources System that were produced by '
#                     'digital mapping of such units, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-16',
#   'description': 'Strengthening Coastal Communities Act',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'result': 'Passed',
#   'roll_call': '419',
#   'session': '2',
#   'time': '10:49:00',
#   'total': {'no': 1, 'not_voting': 54, 'present': 0, 'yes': 375},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/419.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hres1142-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hres1142.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'H RES 1142',
#            'sponsor_id': 'N000189',
#            'title': 'Providing for consideration of the bill (H.R. 6784) to '
#                     'provide for removal of the gray wolf in the contiguous 48 '
#                     'States from the List of Endangered and Threatened '
#                     'Wildlife published under the Endangered Species Act of '
#                     '1973, and providing for proceedings during the period '
#                     'from November 19, 2018, through November 26, 2018.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-14',
#   'description': 'Providing for consideration of H.R. 6784, the Manage our '
#                  'Wolves Act; and providing for proceedings during the period '
#                  'from November 19, 2018, through November 26, 2018',
#   'member_id': 'G000585',
#   'position': 'Not Voting',
#   'question': 'On Agreeing to the Resolution',
#   'result': 'Passed',
#   'roll_call': '418',
#   'session': '2',
#   'time': '17:07:00',
#   'total': {'no': 187, 'not_voting': 42, 'present': 0, 'yes': 201},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/418.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr2615-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr2615.json',
#            'latest_action': 'Became Public Law No: 115-279.',
#            'number': 'H R 2615',
#            'sponsor_id': 'P000601',
#            'title': 'To authorize the exchange of certain land located in Gulf '
#                     'Islands National Seashore, Jackson County, Mississippi, '
#                     'between the National Park Service and the Veterans of '
#                     'Foreign Wars, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-13',
#   'description': 'Gulf Islands National Seashore Land Exchange Act',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Concur in the Senate '
#               'Amendment',
#   'result': 'Passed',
#   'roll_call': '417',
#   'session': '2',
#   'time': '19:24:00',
#   'total': {'no': 1, 'not_voting': 54, 'present': 0, 'yes': 375},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/417.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6064-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6064.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Environment and '
#                             'Public Works.',
#            'number': 'H R 6064',
#            'sponsor_id': 'S001201',
#            'title': 'To rename the Oyster Bay National Wildlife Refuge as the '
#                     'Congressman Lester Wolff National Wildlife Refuge.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-11-13',
#   'description': 'To rename the Oyster Bay National Wildlife Refuge as the '
#                  'Congressman Lester Wolff National Wildlife Refuge',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'result': 'Passed',
#   'roll_call': '416',
#   'session': '2',
#   'time': '18:57:00',
#   'total': {'no': 4, 'not_voting': 36, 'present': 2, 'yes': 385},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/416.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hres1099-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hres1099.json',
#            'latest_action': 'Motion to reconsider laid on the table Agreed to '
#                             'without objection.',
#            'number': 'H RES 1099',
#            'sponsor_id': 'W000791',
#            'title': 'Providing for the concurrence by the House in the Senate '
#                     'amendment to H.R. 6, with an amendment.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-09-28',
#   'description': 'Providing for the concurrence by the House in the Senate '
#                  'amendment to H.R. 6, with an amendment',
#   'member_id': 'G000585',
#   'position': 'Not Voting',
#   'question': 'On Motion to Suspend the Rules and Agree',
#   'result': 'Passed',
#   'roll_call': '415',
#   'session': '2',
#   'time': '12:22:00',
#   'total': {'no': 8, 'not_voting': 27, 'present': 0, 'yes': 393},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/415.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6760-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6760.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Finance.',
#            'number': 'H R 6760',
#            'sponsor_id': 'D000619',
#            'title': 'To amend the Internal Revenue Code of 1986 to make '
#                     'permanent certain provisions of the Tax Cuts and Jobs Act '
#                     'affecting individuals, families, and small businesses.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-09-28',
#   'description': 'Protecting Family and Small Business Tax Cuts Act of 2018',
#   'member_id': 'G000585',
#   'position': 'No',
#   'question': 'On Passage',
#   'result': 'Passed',
#   'roll_call': '414',
#   'session': '2',
#   'time': '12:06:00',
#   'total': {'no': 191, 'not_voting': 18, 'present': 0, 'yes': 220},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/414.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6760-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6760.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Finance.',
#            'number': 'H R 6760',
#            'sponsor_id': 'D000619',
#            'title': 'To amend the Internal Revenue Code of 1986 to make '
#                     'permanent certain provisions of the Tax Cuts and Jobs Act '
#                     'affecting individuals, families, and small businesses.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-09-28',
#   'description': 'Protecting Family and Small Business Tax Cuts Act of 2018',
#   'member_id': 'G000585',
#   'position': 'Yes',
#   'question': 'On Motion to Recommit with Instructions',
#   'result': 'Failed',
#   'roll_call': '413',
#   'session': '2',
#   'time': '11:57:00',
#   'total': {'no': 226, 'not_voting': 18, 'present': 0, 'yes': 184},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/413.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6756-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6756.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Finance.',
#            'number': 'H R 6756',
#            'sponsor_id': 'B001260',
#            'title': 'To amend the Internal Revenue Code of 1986 to promote new '
#                     'business innovation, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-09-27',
#   'description': 'American Innovation Act of 2018',
#   'member_id': 'G000585',
#   'position': 'No',
#   'question': 'On Passage',
#   'result': 'Passed',
#   'roll_call': '412',
#   'session': '2',
#   'time': '16:19:00',
#   'total': {'no': 156, 'not_voting': 12, 'present': 0, 'yes': 260},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/412.json'},
#  {'amendment': {},
#   'bill': {'bill_id': 'hr6757-115',
#            'bill_uri': 'https://api.propublica.org/congress/v1/115/bills/hr6757.json',
#            'latest_action': 'Received in the Senate and Read twice and '
#                             'referred to the Committee on Finance.',
#            'number': 'H R 6757',
#            'sponsor_id': 'K000376',
#            'title': 'To amend the Internal Revenue Code of 1986 to encourage '
#                     'retirement and family savings, and for other purposes.'},
#   'chamber': 'House',
#   'congress': '115',
#   'date': '2018-09-27',
#   'description': 'Family Savings Act of 2018',
#   'member_id': 'G000585',
#   'position': 'No',
#   'question': 'On Passage',
#   'result': 'Passed',
#   'roll_call': '411',
#   'session': '2',
#   'time': '16:10:00',
#   'total': {'no': 177, 'not_voting': 11, 'present': 0, 'yes': 240},
#   'vote_uri': 'https://api.propublica.org/congress/v1/115/house/sessions/2/votes/411.json'}]

# %% [markdown]
# ### identify votes cast since last vote tracked

# %%
last_votes = {}

with open('../data/last_votes.json', 'r') as ofile:
    last_votes = json.loads(ofile.read())
ofile.close()


new_votes = []

for member in all_recent_member_votes:
    for vote in member:
        if vote["roll_call"] > last_votes[vote["member_id"]]:
            new_votes.append(vote)

# %% [markdown]
# ### craft the tweet text from vote dit

# %%
congress_conversions = {'115': '115th', '116': '116th', '117': '117th', '118': '118th', '119': '119th', '120': '120th', '121': '121st', '122': '122nd', '123': '123rd'}

max_tweet_len = 280
link_len = 23
allowed_text_length = max_tweet_len - link_len - 5

for vote in new_votes:
    t_text = ""
    member_dict = [x for x in member_list if x["id"] == vote["member_id"]][0]
#     full_name = member_dict["role"][0:3] + ". " + member_dict["name"] + " (" + member_dict["party"] + ")" 
    try:
        full_name = ".@" + member_dict["twitter_id"] + " (" + member_dict["party"] + ")" 
    except:
        full_name = member_dict["role"][0:3] + ". " + member_dict["name"] + " (" + member_dict["party"] + ")" 
    if vote["position"].lower() != "not voting":
        t_text = t_text + full_name + " voted "
        t_text = t_text + vote['position'].lower()
    else:
        t_text = t_text = t_text + full_name + " did not vote"
    t_text = t_text + " on "
    t_text = t_text + vote["bill"]['number']  
    if vote['bill']['title'] != None:
        t_text = t_text + ', ' + vote['bill']['title'].replace("A bill", "a bill")
    
#     if this is a nomination
    if 'nomination' in vote:
        t_text = t_text + ": the nomination of " + vote["description"]
    
    
    
    
    if len(t_text) > allowed_text_length:
        t_text = t_text[0:allowed_text_length] + "... "
        
    congress_ord = congress_conversions[vote["congress"]]
    bill_nums =  [x for x in list(vote["bill"]["number"]) if x.isdigit()]
    bill_num = "".join(bill_nums)
    bill_chamber = "senate"
    if "H" in vote['bill']['number'].upper():
        bill_chamber = "house"
    congress_gov_url = "https://www.congress.gov/bill/"+ congress_ord +"-congress/" + bill_chamber + "-bill/"+ bill_num
    if 'nomination' in vote:
        congress_gov_url = "https://www.congress.gov/nomination/"+ congress_ord +"-congress/" + vote["nomination"]["number"][2:]
    
    t_text = t_text + " " + congress_gov_url
    vote["t_text"] = t_text
    print(    vote["t_text"])
    print()
# Out:
# .@SenFeinstein (D) voted yes on S.J.Res.64, A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of the Treasury relating to &quot;Returns by Exempt Organizat...  https://www.congress.gov/bill/115th-congress/senate-bill/64
#
# .@SenFeinstein (D) voted yes on H.R.2, To provide for the reform and continuation of agricultural and other programs of the Department of Agriculture through fiscal year 2023, and for other purposes. https://www.congress.gov/bill/115th-congress/house-bill/2
#
# .@SenKamalaHarris (D) voted yes on S.J.Res.64, A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of the Treasury relating to &quot;Returns by Exempt Organi...  https://www.congress.gov/bill/115th-congress/senate-bill/64
#
# .@SenKamalaHarris (D) voted yes on H.R.2, To provide for the reform and continuation of agricultural and other programs of the Department of Agriculture through fiscal year 2023, and for other purposes. https://www.congress.gov/bill/115th-congress/house-bill/2
#
# .@Rep_Hunter (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepMcClintock (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@KenCalvert (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJimCosta (D) did not vote on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepSusanDavis (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepAnnaEshoo (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@DarrellIssa (R) did not vote on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepZoeLofgren (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepBarbaraLee (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@DorisMatsui (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@GOPLeader (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepMcNerney (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@GraceNapolitano (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepDevinNunes (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# Rep. Dana Rohrabacher (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepRoybalAllard (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepEdRoyce (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@BradSherman (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepAdamSchiff (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepLindaSanchez (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepMaxineWaters (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepSpeier (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepGaramendi (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@NancyPelosi (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJudyChu (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepThompson (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJeffDenham (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepKarenBass (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepLaMalfa (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepHuffman (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepPaulCook (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepSwalwell (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepDavidValadao (R) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@JuliaBrownley26 (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepCardenas (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepMarkTakano (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepLowenthal (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJuanVargas (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepBera (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@CongressmanRuiz (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepScottPeters (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepDeSaulnier (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@SteveKnight25 (R) did not vote on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepTedLieu (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@NormaJTorres (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepMimiWalters (R) did not vote on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@reppeteaguilar (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepRoKhanna (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJimmyPanetta (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepCarbajal (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepBarragan (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepLouCorrea (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825
#
# .@RepJimmyGomez (D) voted yes on S 825, a bill to provide for the conveyance of certain property to the Southeast Alaska Regional Health Consortium located in Sitka, Alaska, and for other purposes. https://www.congress.gov/bill/115th-congress/senate-bill/825

# %% [markdown]
# ### send the tweets

# %%
# # send tweets here
# auth = tweepy.OAuthHandler(os.environ["T_CONSUMER_KEY"],os.environ["T_CONSUMER_SECRET"])
# auth.set_access_token(os.environ["T_ACCESS_TOKEN"],os.environ["T_ACCESS_TOKEN_SECRET"])
# api = tweepy.API(auth)
    
    
# for vote in new_votes:
#     print(vote["t_text"])
#     print()
#     api.update_status(status=vote["t_text"])

# %% [markdown]
# ### track the last vote for each member

# %%
most_recent_roll_calls = {}

for member in all_recent_member_votes:
    most_recent_roll_calls[member[0]["member_id"]] = member[0]["roll_call"]
    
with open('../data/last_votes.json', 'w') as ofile:
    ofile.write(json.dumps(most_recent_roll_calls))
ofile.close()
